# %% [markdown]
# <a href="https://www.kaggle.com/code/piyush242002/iris-flower-detection?scriptVersionId=141095040" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **IRIS FLOWER DETECTION**

# %% [markdown]
# # **GENESIS: BIRTH OF DATA**

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/iris-flower-dataset/IRIS.csv")
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# # **NOVA: THE PREPROCESSING**

# %%
from sklearn.preprocessing import LabelEncoder
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
df["species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
species_count = df['species'].value_counts()

# %%
setosa = df[df["species"] == "Iris-setosa"]
setosa.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
versicolor = df[df["species"] == "Iris-versicolor"]
versicolor.head(5)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor

# %%
virginica = df[df["species"] == "Iris-virginica"]
virginica.head(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica

# %%
df["transformed_species"] = LabelEncoder().fit_transform(df["species"])
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    transformed_species
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# # **DRISHTI: THE DATA VISUALIZATION**

# %%
import seaborn as sb
import matplotlib.pyplot as mpl

# %%
sb.set(style = "dark", font = "Times New Roman")

# %% [markdown]
# ### **Sepal Length**

# %%
ax = sb.histplot(data = df, x = "sepal_length", hue = "species", multiple = "stack")
ax.set_title("Frequency of Different Sepal Length for Different Species")
ax.set_xlabel("Sepal Length")
ax.set_ylabel("Frequency")
mpl.show()

# %%
ax = sb.boxplot(data = df, x = "species", y = "sepal_length")
ax.set_title("Box Plot for Sepal Length")
ax.set_xlabel("Species of Iris Flower")
ax.set_ylabel("Sepal Length")
mpl.show()

# %%
ax = sb.violinplot(data = df, x = "species", y = "sepal_length")
ax.set_title("Sepal Length Distribution by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Sepal Length")
mpl.show()

# %%
ax = sb.stripplot(data=df, x="species", y="sepal_length", hue = "species", jitter=True)
ax.set_title("Sepal Length Distribution by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Sepal Length")
mpl.show()

# %%
ax = sb.barplot(data=df, x="species", y="sepal_length", errorbar="sd")
ax.set_title("Mean Sepal Length by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Mean Sepal Length")
mpl.show()

# %% [markdown]
# ### **Sepal Width**

# %%
ax = sb.histplot(data = df, x = "sepal_width", hue = "species", multiple = "stack")
ax.set_title("Frequency of Different Sepal Length for Different Species")
ax.set_xlabel("Sepal Width")
ax.set_ylabel("Frequency")
mpl.show()

# %%
ax = sb.boxplot(data = df, x = "species", y = "sepal_width")
ax.set_title("Box Plot for Sepal Length")
ax.set_xlabel("Species of Iris Flower")
ax.set_ylabel("Sepal Width")
mpl.show()

# %%
ax = sb.violinplot(data = df, x = "species", y = "sepal_width")
ax.set_title("Sepal Width Distribution by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Sepal Width")
mpl.show()

# %%
ax = sb.stripplot(data=df, x="species", y="sepal_width", hue = "species", jitter=True)
ax.set_title("Sepal Width Distribution by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Sepal Width")
mpl.show()

# %%
ax = sb.barplot(data=df, x="species", y="sepal_width", errorbar="sd")
ax.set_title("Mean Sepal Width by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Mean Sepal Width")
mpl.show()

# %% [markdown]
# ### **Petal Length**

# %%
ax = sb.histplot(data = df, x = "petal_length", hue = "species", multiple = "stack")
ax.set_title("Frequency of Different Petal Length for Different Species")
ax.set_xlabel("Petal Length")
ax.set_ylabel("Frequency")
mpl.show()

# %%
ax = sb.boxplot(data = df, x = "species", y = "petal_length")
ax.set_title("Box Plot for Petal Length")
ax.set_xlabel("Species of Iris Flower")
ax.set_ylabel("Petal Length")
mpl.show()

# %%
ax = sb.violinplot(data = df, x = "species", y = "petal_length")
ax.set_title("Petal Length Distribution by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Petal Length")
mpl.show()

# %%
ax = sb.stripplot(data=df, x="species", y="petal_length", hue = "species", jitter=True)
ax.set_title("Petal Length Distribution by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Petal Length")
mpl.show()

# %%
ax = sb.barplot(data=df, x="species", y="petal_length", errorbar="sd")
ax.set_title("Mean Petal Length by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Mean Petal Length")
mpl.show()

# %% [markdown]
# ### **Petal Width**

# %%
ax = sb.histplot(data = df, x = "petal_width", hue = "species", multiple = "stack")
ax.set_title("Frequency of Different Sepal Length for Different Species")
ax.set_xlabel("Petal Width")
ax.set_ylabel("Frequency")
mpl.show()

# %%
ax = sb.boxplot(data = df, x = "species", y = "petal_width")
ax.set_title("Box Plot for Petal Width")
ax.set_xlabel("Species of Iris Flower")
ax.set_ylabel("Petal Width")
mpl.show()

# %%
ax = sb.violinplot(data = df, x = "species", y = "petal_width")
ax.set_title("Petal Width Distribution by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Petal Width")
mpl.show()

# %%
ax = sb.stripplot(data=df, x="species", y="petal_width", hue = "species", jitter=True)
ax.set_title("Petal Width Distribution by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Petal Width")
mpl.show()

# %%
ax = sb.barplot(data=df, x="species", y="petal_width", errorbar="sd")
ax.set_title("Mean Petal Width by Species")
ax.set_xlabel("Species")
ax.set_ylabel("Mean Petal Width")
mpl.show()

# %% [markdown]
# ### **Culminate**

# %%
mpl.pie(species_count, labels=species_count.index, autopct='%1.1f%%', startangle=140)
mpl.title("Distribution of Flower Species")
mpl.show()

# %%
ax = sb.pairplot(data = df, hue = "species")
mpl.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
correlation_matrix = df.corr(numeric_only = True)
ax = sb.heatmap(correlation_matrix, annot=True)
ax.set_title("Correlation Heatmap")
mpl.show()

# %% [markdown]
# # **KINETIC: SPLITTING THE DATA**

# %%
from sklearn.model_selection import train_test_split

# %%
Input = df.drop(["species", "transformed_species"], axis = 1)
Output = df.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(Input, Output, test_size = 0.2, random_state = 1)

# %% [markdown]
# # **FINAL BATTLE: THE MODEL**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score as score

# %%
LR = LogisticRegression()
LR.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
PredictedValue = LR.predict(x_test)
print("Accuracy = {:0.2f}%".format(score(PredictedValue, y_test)*100))
# Out:
# Accuracy = 96.67%
